# %% [markdown]
# ### Assignment 2

# %%
import re

# %% [markdown]
# ##### Question 1

# %%
class Q1:

    def start_search(self, d):

        ### REPLACE THE BELOW LINE WITH YOUR CODE ###
        ### DO NOT EDIT ANYTHING ELSE IN THIS FUNCTION ###
        self.pattern = r'(?<!\d)(?!\d{3}|00)\d{2}\.\d{2}(?!\d)'

        next = "00.00+00.00"
        while next:
            p = re.compile(self.pattern)
            m = p.findall(d[next])
            if not m:
                break
            next = "+".join(m)

        return next

# %%
# run this code to get the feedback for question 1
with open('q1.txt', 'w') as f:
    score = 0

    q1 = Q1()
    ### open test case # 1 ###
    d = {
        "00.00+00.00": "The next treasure is at 12.34 and 23.45",
        "12.34+23.45": "The fake treasure is in 222.11 and 11.11 and 14.56",
        "222.11+11.11+14.56": "Welcome to your infinite loop at 00.00 and 00.00",
        "222.11+11.11": "Welcome to your infinite loop at 12.34 and 23.45",
        "11.11+14.56": "Congrats!",
    }
    if q1.start_search(d) == "11.11+14.56":
        score += 1
        f.write('[1/1] first sample case is matched\n')
    else:
        f.write('[0/1] first sample case is not matched\n')

    ### open test case # 2 ###
    d = {
        "00.00+00.00": "The next treasure is at 16.88 and 26.84",
        "16.88+26.84": "The fake treasure is in 00.13 and 55.66 and 14.56",
        "00.13+55.66+14.56": "Welcome to your infinite loop at 00.00 and 00.00",
        "00.13+55.66": "Welcome to your infinite loop at 16.88 and 26.84",
        "55.66+14.56": "Seek 12.1 and you shall find24.55and 14.56.",
        "24.55+14.56": "Congrats!",
    }
    if q1.start_search(d) == "24.55+14.56":
        score += 1
        f.write('[1/1] second sample case is matched\n')
    else:
        f.write('[0/1] second sample case is not matched\n')

    ### test that the length of pattern is less than or equal to 50 characters ###
    if len(q1.pattern) <= 50:
        score += 1
        f.write('[1/1] pattern is less than or equal to 50 characters\n')
    else:
        f.write('[0/1] pattern is longer than 50 characters\n')

# %% [markdown]
# ##### Question 2

# %%
class Q2:

    def crossword_puzzle(self, s, l):
        ### DO NOT EDIT THIS PART ###
        self.m = len(s.split("\n"))
        self.n = len(s.split("\n")[0])

        # part 1: prepare the pattern variable
        self.pattern = []  # list of patterns to be used for part 2
        self.line_pattern = r"(\w) in the (\d+) position"  # regex to extract character and position

        for instructions in l:
            if "length" not in instructions:
                # Direct word pattern with word boundaries
                pattern = r"\b" + re.escape(instructions) + r"\b"
                self.pattern.append(pattern)
            else:
                # Extract character-position pairs
                matches = re.findall(self.line_pattern, instructions)
                length_match = re.search(r'length (\d+)', instructions)
                if length_match:
                    length = int(length_match.group(1))
                    # Initialize pattern with wildcards
                    pattern_chars = ['.'] * length
                    for char, pos in matches:
                        pos = int(pos)
                        if 0 <= pos < length and pos < self.n:
                            pattern_chars[pos] = re.escape(char)
                        else:
                            print(f"Warning: Position {pos} out of bounds for length {length} and grid columns {self.n}")
                    # Create regex pattern for the word
                    regex = '^' + ''.join(pattern_chars) + '$'
                    self.pattern.append(regex)

        # part 2: extract all possible sequences (rows, columns, diagonals)
        grid = [list(line) for line in s.split("\n")]

        # Extract rows
        rows = [''.join(row) for row in grid]

        # Extract columns
        columns = [''.join([grid[r][c] for r in range(self.m)]) for c in range(self.n)]

        # Extract main diagonals (top-left to bottom-right)
        main_diagonals = []
        for k in range(-self.m + 1, self.n):
            diagonal = ''.join([grid[r][c] for r in range(self.m) for c in range(self.n) if c - r == k])
            if len(diagonal) >= 1:
                main_diagonals.append(diagonal)

        # Extract anti-diagonals (top-right to bottom-left)
        anti_diagonals = []
        for k in range(self.m + self.n -1):
            diagonal = ''.join([grid[r][c] for r in range(self.m) for c in range(self.n) if r + c == k])
            if len(diagonal) >= 1:
                anti_diagonals.append(diagonal)

        # Combine all sequences
        all_sequences = rows + columns + main_diagonals + anti_diagonals

        # Compile all patterns
        compiled_patterns = [re.compile(pat) for pat in self.pattern]

        matched_words = set()

        # Check each sequence against all patterns
        for pat in compiled_patterns:
            for sequence in all_sequences:
                matches = pat.findall(sequence)
                for match in matches:
                    # If the pattern uses word boundaries or exact matching, match will be the word
                    if isinstance(match, str):
                        matched_words.add(match)
                    elif isinstance(match, tuple):
                        # In case of multiple groups, join them
                        matched_word = ''.join(match)
                        matched_words.add(matched_word)

        if matched_words:
            print(matched_words)
            return list(matched_words)[0]
        else:
            return ["No match found"]

# %%
# run this code to get the feedback for question 2
with open('q2.txt', 'w') as f:
    score = 0

    q2 = Q2()

    ### open test case # 1 ###
    s = '''abc
gar
tvd''' # the indentation here is NOT an ERROR
    l = [
        'bat',
        'a length 3 word with g in the 0 position, a in the 1 position, t in the 2 position',
        'a length 3 word with a in the 1 position, t in the 2 position'
    ]
    if q2.crossword_puzzle(s, l) == "cat":
        score += 1
        f.write('[1/1] first sample case is matched\n')
    else:
        f.write('[0/1] first sample case is not matched\n')

    ### open test case # 2 ###
    s = '''heluo
yello
bello
mello''' # the indentation here is NOT an ERROR
    l = [
        'hellu',
        'a length 2 word with a in the 0 position',
        'a length 4 word with h in the 0 position, y in the 1 position, n in the 3 position',
        'a length 4 word with h in the 0 position, l in the 2 position, l in the 3 position'
    ]
    if q2.crossword_puzzle(s, l) == "hell":
        score += 1
        f.write('[1/1] second sample case is matched\n')
    else:
        f.write('[0/1] second sample case is not matched\n')

    if q2.pattern and type(q2.pattern) == list:
        try:
            ### test that the pattern contains regular expression patterns ###
            count = 0
            for pattern in q2.pattern: # this checks that self.pattern contains valid regular expressions that works with the given code for part 2
                p = re.compile(pattern)
                m = p.findall(s)
                if len(m) == 1:
                    count += 1
            if count == 1:
                score += 2
                f.write('[2/2] 1(a) pattern contains regular expressions that gives exactly one match\n')
            elif count > 0:
                score += 1
                f.write('[1/2] 1(a) pattern contains regular expressions that gives more than one match\n')
            else:
                f.write('[0/2] 1(a) pattern contains regular expressions that gives no match\n')

            ### test that part 2 works with the given solution ###
            if count > 0:
                score += 2
                f.write('[2/2] 2(b) part 2 works with the provided code\n')
            else:
                f.write('[0/2] 2(b) part 2 does not work with the provided code\n')
        except:
            f.write('[0/2] 1(a) pattern contains invalid regular expressions\n')

        ### tests that solution creates ONE regular expression for each string in l, i.e., length of pattern == length of l
        if len(q2.pattern) == len(l):
            score += 2
            f.write('[2/2] 1(c) length of pattern == length of l\n')
        else:
            f.write('[0/2] 1(c) length of pattern != length of l\n')
# Out:
# {'cat'}
# {'hell'}

# %% [markdown]
# #### Question 3

# %%
from operator import is_
from tabnanny import check


class Weapon:

    def __init__(self, damage, range):
        self.damage = damage
        self.range = range
        self.durability = 10
        self.is_broken = False
        
    def attack(self, monster):     
        
        if self.is_broken:
            return None
        else:
            monster.health -= self.damage
            self.durability -= 1
            monster.attack(self)
            self.check_broken()
        
        return None
        
    def check_broken(self):
        if self.durability <= 0:
            self.is_broken = True
        return None

class Monster:

    def __init__(self, damage):
        self.damage = damage
        self.health = 10
        self.is_alive = True

    def check_alive(self):
        if self.health <= 0:
            self.is_alive = False
        return self.is_alive

class RangeMonster(Monster):

    def __init__(self, damage, range):
        super().__init__(damage)
        self.range = range
        
    def attack(self, weapon):
        
        self.check_alive()
        
        if self.is_alive and self.range >= weapon.range:
            weapon.durability -= self.damage
        return None

class MeleeMonster(Monster):

    def __init__(self, damage):
        super().__init__(damage)
        self.range = 1
        
    def attack(self, weapon):
        
        self.check_alive()
        
        if self.is_alive and self.range >= weapon.range:
            weapon.durability -= self.damage*2
        return None

# %%
with open('q3.txt', 'w') as f:
    score = 0

    ### open test case # 1 ###
    try:
        w1 = Weapon(5, 5)
        # test that the weapon is created correctly
        assert w1.damage == 5
        assert w1.range == 5
        assert w1.durability == 10
        assert w1.is_broken == False

        w2 = Weapon(3, 1)
        # test that the weapon is created correctly
        assert w2.damage == 3
        assert w2.range == 1
        assert w2.durability == 10
        assert w2.is_broken == False

        rm1 = RangeMonster(5, 3)
        # test that the monster is created correctly
        assert rm1.damage == 5
        assert rm1.range == 3
        assert rm1.health == 10
        assert rm1.is_alive == True
        
        mm1 = MeleeMonster(5)
        # test that the monster is created correctly
        assert mm1.damage == 5
        assert mm1.range == 1
        assert mm1.health == 10
        assert mm1.is_alive == True

        # test that the weapon can attack the monster
        w1.attack(rm1)
        assert rm1.health == 5
        assert rm1.is_alive == True
        assert w1.durability == 9
        assert w1.is_broken == False

        w2.attack(rm1)
        assert rm1.health == 2
        assert rm1.is_alive == True
        assert w2.durability == 4
        assert w2.is_broken == False

        w2.attack(rm1)
        assert rm1.health == -1
        assert rm1.is_alive == False
        assert w2.durability == 3
        assert w2.is_broken == False

        w2.attack(mm1)
        assert mm1.health == 7
        assert mm1.is_alive == True
        assert w2.durability == -8
        assert w2.is_broken == True

        w1.attack(mm1)
        assert mm1.health == 2
        assert mm1.is_alive == True
        assert w1.durability == 8
        assert w1.is_broken == False
        
        score += 1
        f.write('[1/1] open test case 1 is matched\n')

    except Exception as e:
        print(e)
        f.write('[0/1] open test case 1 is not matched\n')

    ### open test case # 2 ###
    try:
        w1 = Weapon(3, 3)
        # test that the weapon is created correctly
        assert w1.damage == 3
        assert w1.range == 3
        assert w1.durability == 10
        assert w1.is_broken == False

        w2 = Weapon(5, 1)
        # test that the weapon is created correctly
        assert w2.damage == 5
        assert w2.range == 1
        assert w2.durability == 10
        assert w2.is_broken == False

        rm1 = RangeMonster(5, 3)
        # test that the monster is created correctly
        assert rm1.damage == 5
        assert rm1.range == 3
        assert rm1.health == 10
        assert rm1.is_alive == True
        
        mm1 = MeleeMonster(5)
        # test that the monster is created correctly
        assert mm1.damage == 5
        assert mm1.range == 1
        assert mm1.health == 10
        assert mm1.is_alive == True

        # test that the weapon can attack the monster
        w1.attack(rm1)
        assert rm1.health == 7
        assert rm1.is_alive == True
        assert w1.durability == 4
        assert w1.is_broken == False

        w2.attack(rm1)
        assert rm1.health == 2
        assert rm1.is_alive == True
        assert w2.durability == 4
        assert w2.is_broken == False

        w2.attack(rm1)
        assert rm1.health == -3
        assert rm1.is_alive == False
        assert w2.durability == 3
        assert w2.is_broken == False

        w2.attack(mm1)
        assert mm1.health == 5
        assert mm1.is_alive == True
        assert w2.durability == -8
        assert w2.is_broken == True

        w1.attack(mm1)
        assert mm1.health == 2
        assert mm1.is_alive == True
        assert w1.durability == 3
        assert w1.is_broken == False

        w1.attack(mm1)
        assert mm1.health == -1
        assert mm1.is_alive == False
        assert w1.durability == 2
        assert w1.is_broken == False
        
        score += 1
        f.write('[1/1] open test case 2 is matched\n')
    except:
        f.write('[0/1] open test case 2 is not matched\n')

    ### open test case # 3 ###
    try:
        w1 = Weapon(5, 1)
        # test that the weapon is created correctly
        assert w1.damage == 5
        assert w1.range == 1
        assert w1.durability == 10
        assert w1.is_broken == False

        rm1 = RangeMonster(4, 3)
        # test that the monster is created correctly
        assert rm1.damage == 4
        assert rm1.range == 3
        assert rm1.health == 10
        assert rm1.is_alive == True
        
        mm1 = MeleeMonster(3)
        # test that the monster is created correctly
        assert mm1.damage == 3
        assert mm1.range == 1
        assert mm1.health == 10
        assert mm1.is_alive == True

        # test that the weapon can attack the monster
        w1.attack(rm1)
        assert rm1.health == 5
        assert rm1.is_alive == True
        assert w1.durability == 5
        assert w1.is_broken == False

        w1.attack(mm1)
        assert mm1.health == 5
        assert mm1.is_alive == True
        assert w1.durability == -2
        assert w1.is_broken == True

        score += 1
        f.write('[1/1] open test case 3 is matched\n')
    except:
        f.write('[0/1] open test case 3 is not matched\n')
